# %% [markdown]
# <a href="https://colab.research.google.com/github/AnulipiJana/AI-Driven-Supply-Chain-Disruption-Predictor-and-Inventory-Optimization-System/blob/main/Milestone2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Product : TOMATO

# %% [markdown]
# ### Try to fetch information about tomatos supply chain management using news api

# %%
import requests
import pandas as pd

API_KEY = "f77ec218c74644348641d36d500f126a"
API_URL = "https://newsapi.org/v2/everything"

# Function to fetch news
def news_fetch(query="tomato supply chain", page_size=50, language="en"):
    parameters = {
        "q": query,
        "pageSize": page_size,  # Number of articles per request
        "language": language,
        "apiKey": API_KEY,
    }
    response = requests.get(API_URL, params=parameters) #Sends a GET request to the NewsAPI with the specified parameters
    if response.status_code == 200:
        articles = response.json().get("articles", [])
        return articles
    else:
        print(f"Error: {response.status_code}")
        return []

# Main function
if __name__ == "__main__":
    # Fetch news articles
    articles = news_fetch()
    if articles:
        print("SUCCESSFUL !\n")

        # Collect relevant fields and create a DataFrame
        news_data = [
            {
                "Title": article["title"],
                "Description": article["description"],
                "Source": article["source"]["name"],
                "URL": article["url"],
            }
            for article in articles
        ]
        news_df = pd.DataFrame(news_data)

        news_df.to_csv("Tomato_supply_chain_news.csv", index=True) # Save to CSV

        # Print in the requested format (Row {idx + 1}: Title, Description, Source, URL)
        print("\nArticle Information:")
        for idx, row in news_df.iterrows():
            print(f"Row {idx + 1}:")
            print(f"Title: {row['Title']}")
            print(f"Description: {row['Description']}")
            print(f"Source: {row['Source']}")
            print(f"URL: {row['URL']}")
            print("\n")
    else:
        print("No articles found.")
# Out:
# SUCCESSFUL !
#
#
# Article Information:
# Row 1:
# Title: China's farm sector more tainted by forced labor than previously known, report says
# Description: Chinese exports of tomatoes, chili peppers, marigolds and other farm products grown in the far-western region of Xinjiang are tainted by forced labor as well as the coercive transfer of land from Uyghur peasants to Chinese businesses, new research shows.
# Source: Globalsecurity.org
# URL: https://www.globalsecurity.org/wmd/library/news/china/2024/12/china-241219-rfa01.htm
#
#
# Row 2:
# Title: The European Art of Taste celebrates Tomato, an icon of European taste and quality
# Description: Fresh or processed, tomato is the beating heart of Mediterranean cuisine, prized for its unmistakable flavour and exceptional nutritional properties, is the star of the ‘Postcards from Europe’ series Fresh or processed, tomato is the beating heart of Mediterr…
# Source: GlobeNewswire
# URL: https://www.globenewswire.com/news-release/2025/01/03/3003802/0/en/The-European-Art-of-Taste-celebrates-Tomato-an-icon-of-European-taste-and-quality.html
#
#
# Row 3:
# Title: 3 Tips to Start a Sustainable Backyard Farm
# Description: The global urban farming market size should hit USD 290.11 billion by 2032, which tells us that more and more people are getting in on the backyard farming action. Maybe the rising prices at the grocery store or the sight of half-empty shelves during recent y…
# Source: Ahouseinthehills.com
# URL: https://ahouseinthehills.com/3-tips-to-start-a-sustainable-backyard-farm/
#
#
# Row 4:
# Title: Modern slavery is endemic in global supply chains. Companies should be praised – not shamed – for detecting it
# Description: When firms say they have found no evidence of modern slavery, that should ring alarm bells.
# Source: The Conversation Africa
# URL: https://theconversation.com/modern-slavery-is-endemic-in-global-supply-chains-companies-should-be-praised-not-shamed-for-detecting-it-246380
#
#
# Row 5:
# Title: An Authentic Christmas with the taste and magic of European Fruit and Vegetables
# Description: Christmas gets fresh and wholesome with the magical elves of European fruit and vegetables, ready to bring moments of well-being and joy during holidays Christmas gets fresh and wholesome with the magical elves of European fruit and vegetables, ready to bring…
# Source: GlobeNewswire
# URL: https://www.globenewswire.com/news-release/2024/12/23/3000999/0/en/An-Authentic-Christmas-with-the-taste-and-magic-of-European-Fruit-and-Vegetables.html
#
#
# Row 6:
# Title: An Authentic Christmas with the taste and magic of European Fruit and Vegetables
# Description: Christmas gets fresh and wholesome with the magical elves of European fruit and vegetables, ready to bring moments of well-being and joy during holidays Christmas gets fresh and wholesome with the magical elves of European fruit and vegetables, ready to bring…
# Source: GlobeNewswire
# URL: https://www.globenewswire.com/news-release/2024/12/22/3000996/0/en/An-Authentic-Christmas-with-the-taste-and-magic-of-European-Fruit-and-Vegetables.html
#
#
# Row 7:
# Title: Trump lied about food prices. Now he says it's too 'hard' to bring down costs. | Opinion
# Description: Donald Trump said it would be easy to lower food prices. Now he says it's hard. Never trust a con man.
# Source: Newsbreak.com
# URL: https://www.newsbreak.com/share/3713867582595-trump-lied-about-food-prices-now-he-says-it-s-too-hard-to-bring-down-costs-opinion?_f=app_share&amp;pd=0BsB8IAC&amp;lang=en_US&amp;send_time=1734122604&amp;trans_data=%7B%22platform%22%3A0%2C%22cv%22%3A%2224.50.0.34%22%2C%22languages%22%3A%22en%22%7D&amp;sep=ns_local_strategy_24q4_exp-v12%2Cns_foryou_blend_exp_24q4-v7%2Cns_foryou_rank_exp_24q4-v9%2Cns_foryou_recall_exp_24q4-v3%2Cns_foryou_model_exp_24q4-v8%2Cns_push_exp_rt_bucketv12-v7&amp;s=i2
#
#
# Row 8:
# Title: Trump lied about food prices. Now he says it's too 'hard' to bring down costs. | Opinion
# Description: Donald Trump said it would be easy to lower food prices. Now he says it's hard. Never trust a con man.
# Source: Newsbreak.com
# URL: https://www.newsbreak.com/share/3713867582595-trump-lied-about-food-prices-now-he-says-it-s-too-hard-to-bring-down-costs-opinion?_f=app_share&amp;pd=07UN8yyZ&amp;lang=en_US&amp;send_time=1734108231&amp;trans_data=%7B%22platform%22%3A0%2C%22cv%22%3A%2224.50.0.34%22%2C%22languages%22%3A%22en%22%7D&amp;sep=ns_push_exp_rt_bucketv12-v4%2Cns_local_strategy_24q4_exp-control%2Cns_foryou_blend_exp_24q4-v9%2Cns_foryou_rank_exp_24q4-v7%2Cns_foryou_model_exp_24q4-v3%2Cns_foryou_recall_exp_24q4-v3&amp;s=i2
#
#
# Row 9:
# Title: Trump lied about food prices. Now he says it's too 'hard' to bring down costs. | Opinion
# Description: Donald Trump said it would be easy to lower food prices. Now he says it's hard. Never trust a con man.
# Source: Newsbreak.com
# URL: https://www.newsbreak.com/share/3713867582595-trump-lied-about-food-prices-now-he-says-it-s-too-hard-to-bring-down-costs-opinion?_f=app_share&amp;pd=01LmfFGQ&amp;lang=en_US&amp;send_time=1734130372&amp;trans_data=%7B%22platform%22%3A0%2C%22cv%22%3A%2224.50.0.34%22%2C%22languages%22%3A%22en%22%7D&amp;sep=ns_local_strategy_24q4_exp-control%2Cns_foryou_model_exp_24q4-v5%2Cns_foryou_rank_exp_24q4-v5%2Cns_push_exp_rt_bucketv12-v4%2Cns_foryou_recall_exp_24q4-v6%2Cns_foryou_blend_exp_24q4-control&amp;s=i2

# %% [markdown]
# ### Try to fetch information about tomatos supply chain management using kaggle api

# %%
import requests
import pandas as pd

# Constants
API_URL = "https://www.kaggle.com/api/v1/datasets/download/bonifacechosen/tomato-retail-sales-data-2009-2022"
API_KEY = "485aba36b259a5295d30f07a0d031a8f"  # Replace with your API key

def fetch_data_from_api():
    """Fetch data from the API."""
    headers = {
        "Authorization": f"Bearer {API_KEY}"  # Adjust headers as required by your API
    }

    response = requests.get(API_URL, headers=headers)
    if response.status_code == 200:
        try:
            data = response.json()  # Parse JSON response
            return data
        except requests.exceptions.JSONDecodeError:
            print("Response is not in JSON format.")
            return []
    else:
        print(f"API call failed with status code {response.status_code}: {response.text}")
        return []

def save_data_to_csv(data, filename="output.csv"):
    """Save the fetched data to a CSV file."""
    if data:
        # Convert to DataFrame
        df = pd.DataFrame(data)
        # Save to CSV
        df.to_csv(filename, index=False)
        print(f"Data saved to {filename}")
    else:
        print("No data to save.")

if __name__ == "__main__":
    # Fetch data from the API
    api_data = fetch_data_from_api()

    # Save data to a CSV file
    save_data_to_csv(api_data, filename="api_data.csv")
# Out:
# Response is not in JSON format.
# No data to save.

# %%
print(response.headers.get("Content-Type"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ba6825fc3671> in <cell line: 1>()
# ----> 1 print(response.headers.get("Content-Type"))
#
# NameError: name 'response' is not defined

# %%
import requests
import zipfile
import os
import pandas as pd

# API endpoint
API_URL = "https://www.kaggle.com/api/v1/datasets/download/bonifacechosen/tomato-retail-sales-data-2009-2022"

# File paths
ZIP_FILE_PATH = "data.zip"
EXTRACTION_FOLDER = "extracted_files"

# Function to download and extract ZIP file
def download_and_extract_zip(api_url, zip_file_path, extraction_folder):
    response = requests.get(api_url)

    if response.status_code == 200:
        # Save ZIP file locally
        with open(zip_file_path, "wb") as file:
            file.write(response.content)
        print("ZIP file downloaded successfully.")

        # Extract ZIP file
        with zipfile.ZipFile(zip_file_path, "r") as zip_ref:
            if not os.path.exists(extraction_folder):
                os.makedirs(extraction_folder)
            zip_ref.extractall(extraction_folder)
        print(f"Files extracted to {extraction_folder}")
        return True
    else:
        print(f"API call failed with status code {response.status_code}: {response.text}")
        return False

# Function to convert extracted CSV files to pandas DataFrames
def process_csv_files(extraction_folder):
    for root, dirs, files in os.walk(extraction_folder):
        for filename in files:
            if filename.endswith(".csv"):
                file_path = os.path.join(root, filename)
                print(f"Processing file: {file_path}")

                # Load CSV into a DataFrame
                df = pd.read_csv(file_path)

                # Save DataFrame to a new CSV file (optional)
                new_csv_path = f"processed_{filename}"
                df.to_csv(new_csv_path, index=False)
                print(f"Processed CSV saved as: {new_csv_path}")

# Main execution
if __name__ == "__main__":
    if download_and_extract_zip(API_URL, ZIP_FILE_PATH, EXTRACTION_FOLDER):
        process_csv_files(EXTRACTION_FOLDER)
# Out:
# ZIP file downloaded successfully.
# Files extracted to extracted_files
# Processing file: extracted_files/tomato_retail_sales_daily_2009_2022 (1).csv
# Processed CSV saved as: processed_tomato_retail_sales_daily_2009_2022 (1).csv

# %%
import pandas as pd
data=pd.read_csv("/content/extracted_files/tomato_retail_sales_daily_2009_2022 (1).csv")
data
# Out:
#             Date  Quantity Sold (kg)  Unit Price (NGN)  \
# 0       1/1/2009                 139               168
# 1       1/2/2009                 208               155
# 2       1/3/2009                 287               157
# 3       1/4/2009                 118               153
# 4       1/5/2009                 188               127
# ...          ...                 ...               ...
# 5047  10/27/2022                 159               259
# 5048  10/28/2022                 158               226
# 5049  10/29/2022                 159               314
# 5050  10/30/2022                 113               229
# 5051  10/31/2022                 177               267
#
#       Total Sales Value (NGN)  Opening Stock (kg)  Closing Stock (kg)  \
# 0                       23421                 263                 163
# 1                       32261                 179                  57
# 2                       45119                 211                   9
# 3                       18022                 280                 240
# 4                       23788                 244                  85
# ...                       ...                 ...                 ...
# 5047                    41115                 197                 128
# 5048                    35710                 232                 144
# 5049                    49886                 237                 127
# 5050                    25891                 230                 192
# 5051                    47344                 173                   6
#
#       Restocked Quantity (kg)     Supplier Name  Supplier Cost (NGN)  \
# 0                         100      Local Farmer                  127
# 1                         122      Ogun Growers                  122
# 2                         202      Ogun Growers                  128
# 3                          40      Ogun Growers                  110
# 4                         159      Local Farmer                   94
# ...                       ...               ...                  ...
# 5047                       69      Local Farmer                  204
# 5048                       88      Ogun Growers                  160
# 5049                      110       Jigawa Farm                  233
# 5050                       38  Kaduna Suppliers                  186
# 5051                      167  Kaduna Suppliers                  233
#
#       Transport Cost (NGN)    Store Location      Season
# 0                     4690  Kano, Sabon Gari  Dry Season
# 1                     5485       Lagos, Yaba  Dry Season
# 2                     3676            Ibadan  Dry Season
# 3                     3538       Abuja, Wuse  Dry Season
# 4                     6816  Kano, Sabon Gari  Dry Season
# ...                    ...               ...         ...
# 5047                  9306            Ibadan  Dry Season
# 5048                  3057            Ibadan  Dry Season
# 5049                  5309  Kano, Sabon Gari  Dry Season
# 5050                  3238       Abuja, Wuse  Dry Season
# 5051                  6718       Lagos, Yaba  Dry Season
#
# [5052 rows x 12 columns]

# %%
# @title Store Location

from matplotlib import pyplot as plt
import seaborn as sns
data.groupby('Store Location').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ## Final Dataset

# %%
import pandas as pd
data = pd.read_csv("/content/tomato_supply_chain (1).csv")
data
# Out:
#             Date   Region    Country    Supplier  Inventory Level  \
# 0     2024-09-24  Central        USA  Supplier A              593
# 1     2024-02-20    South      India  Supplier B              784
# 2     2024-09-08     East      China  Supplier E              407
# 3     2024-11-26    South     Brazil  Supplier D              109
# 4     2024-10-01     West  Australia  Supplier D              744
# ...          ...      ...        ...         ...              ...
# 9995  2024-04-12     West     Brazil  Supplier A              101
# 9996  2024-07-31    South      India  Supplier D              730
# 9997  2024-08-06  Central      India  Supplier D              337
# 9998  2024-02-04    South    Nigeria  Supplier C              490
# 9999  2024-05-25  Central        USA  Supplier E              623
#
#       Lead Time (days)   Transport Status News Sentiment Risk Factor
# 0                   10            Delayed       Negative      Medium
# 1                   30  Awaiting Dispatch        Neutral         Low
# 2                   24         In Transit        Neutral        High
# 3                   30  Awaiting Dispatch        Neutral      Medium
# 4                    4            Delayed       Negative         Low
# ...                ...                ...            ...         ...
# 9995                 6            On Time       Positive      Medium
# 9996                 5         In Transit       Positive         Low
# 9997                 6  Awaiting Dispatch       Positive         Low
# 9998                15         In Transit       Positive         Low
# 9999                 4  Awaiting Dispatch        Neutral      Medium
#
# [10000 rows x 9 columns]

# %% [markdown]
# # Sentiment and Risk Analysis

# %% [markdown]
# ### model: facebook/bart-large-mnli

# %%
import pandas as pd
from openai import ChatCompletion
from transformers import pipeline

OPENAI_API_KEY = "AIzaSyDCQ1-AUH3C6xU5GGAHxY9QvL_kRZ-OHUY"

# LLM Initialization
def initialize_openai():
    ChatCompletion.api_key = OPENAI_API_KEY

def initialize_llama():
    return pipeline("text-classification", model="facebook/bart-large-mnli")

# risk analysis with OpenAI GPT
def analyze_risk_with_gpt(content):
    try:
        response = ChatCompletion.create(
            model="gpt-4",
            messages=[
                {"role": "system", "content": "You are an expert in supply chain risk analysis."},
                {"role": "user", "content": content}
            ]
        )
        return response.choices[0].message['content']
    except Exception as e:
        print(f"Error with OpenAI GPT: {e}")
        return None

######
# sentiment analysis with LLaMA
def analyze_sentiment_with_llama(content, llama_pipeline):
    try:
        results = llama_pipeline(content)
        return results
    except Exception as e:
        print(f"Error with LLaMA: {e}")
        return None

# Aggregating data from the dataset
def aggregate_data_from_csv(file_path):
    try:
        # Load dataset
        dataset = pd.read_csv(file_path)
        return dataset
    except Exception as e:
        print(f"Error loading dataset: {e}")
        return None

# Main pipeline
def main():
    # Initialize models
    initialize_openai()
    llama_pipeline = initialize_llama()

    # Load dataset
    dataset_path = "/content/tomato_supply_chain (1).csv"
    structured_data = aggregate_data_from_csv(dataset_path)
    if structured_data is None:
        return

    # Analyze risk and sentiment for each row
    results = []
    for _, row in structured_data.iterrows():
        print(f"Analyzing data for Date: {row['Date']}, Region: {row['Region']}, Supplier: {row['Supplier']}")

        # Combine relevant fields for analysis
        content = (f"Region: {row['Region']}, Country: {row['Country']}, Supplier: {row['Supplier']}, "
                   f"Inventory Level: {row['Inventory Level']}, Lead Time: {row['Lead Time (days)']}, "
                   f"Transport Status: {row['Transport Status']}, News Sentiment: {row['News Sentiment']}, "
                   f"Risk Factor: {row['Risk Factor']}")

        gpt_analysis = analyze_risk_with_gpt(content)
        sentiment_analysis = analyze_sentiment_with_llama(content, llama_pipeline)

        results.append({
            "Date": row['Date'],
            "Region": row['Region'],
            "Country": row['Country'],
            "Supplier": row['Supplier'],
            "GPT Risk Analysis": gpt_analysis,
            "Sentiment Analysis": sentiment_analysis
        })

    # Convert results to a DataFrame and save
    results_df = pd.DataFrame(results)
    results_df.to_csv("supply_chain_analysis_results.csv", index=False)
    print("Analysis complete. Results saved to 'supply_chain_analysis_results.csv'.")

if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0
# Analyzing data for Date: 2024-09-24, Region: Central, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-02-20, Region: South, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-09-08, Region: East, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-11-26, Region: South, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-10-01, Region: West, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-05-19, Region: West, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-01-19, Region: Central, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-04-04, Region: Central, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Streaming output truncated to the last 5000 lines.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-04-15, Region: North, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-10-15, Region: East, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-05-30, Region: East, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-01-13, Region: North, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-08-13, Region: North, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-12-28, Region: South, Supplier: Supplier C
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-05-22, Region: South, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-09-21, Region: North, Supplier: Supplier C
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-09-07, Region: Central, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-01-18, Region: North, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-04-04, Region: West, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-07-07, Region: South, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-08-24, Region: North, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-12-09, Region: West, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-08-14, Region: Central, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-05-14, Region: North, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-04-22, Region: North, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-01-20, Region: North, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-06-24, Region: West, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-06-22, Region: South, Supplier: Supplier C
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-02-19, Region: West, Supplier: Supplier C
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-08-07, Region: West, Supplier: Supplier C
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-07-10, Region: Central, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-11-07, Region: Central, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-09-13, Region: Central, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-09-17, Region: South, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-08-25, Region: West, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-10-27, Region: East, Supplier: Supplier C
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-02-28, Region: South, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-01-23, Region: East, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-02-09, Region: North, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-05-17, Region: Central, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-08-25, Region: West, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-03-16, Region: East, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-04-06, Region: East, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-05-21, Region: South, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-09-02, Region: Central, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-09-26, Region: Central, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-10-15, Region: South, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-01-14, Region: West, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-02-18, Region: Central, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-10-02, Region: North, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-07-23, Region: North, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-04-27, Region: West, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-02-22, Region: South, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-07-17, Region: South, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-10-03, Region: South, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-10-27, Region: Central, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-09-06, Region: East, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-08-26, Region: South, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-06-08, Region: West, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-08-08, Region: West, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-04-13, Region: South, Supplier: Supplier C
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-11-02, Region: South, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-09-04, Region: East, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-03-28, Region: East, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-12-07, Region: West, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-03-01, Region: West, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-05-09, Region: East, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-03-21, Region: East, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-06-12, Region: North, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-09-11, Region: West, Supplier: Supplier C
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-03-22, Region: Central, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-03-29, Region: South, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-01-23, Region: East, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-01-06, Region: Central, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-03-22, Region: East, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-07-06, Region: West, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-04-24, Region: Central, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-06-08, Region: East, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-07-09, Region: South, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-04-06, Region: North, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-04-24, Region: East, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-10-08, Region: Central, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-12-02, Region: West, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# ...
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-03-08, Region: Central, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-06-24, Region: South, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-11-29, Region: East, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-12-17, Region: West, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-07-27, Region: West, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-06-26, Region: South, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-09-07, Region: Central, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-03-23, Region: West, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-04-12, Region: North, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-06-06, Region: South, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-12-09, Region: East, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-02-03, Region: North, Supplier: Supplier C
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-06-08, Region: South, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-11-06, Region: East, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-10-20, Region: South, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-04-21, Region: South, Supplier: Supplier C
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-06-20, Region: Central, Supplier: Supplier C
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-07-25, Region: North, Supplier: Supplier C
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-02-12, Region: North, Supplier: Supplier B
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-04-08, Region: South, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-11-26, Region: East, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-11-01, Region: West, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-10-17, Region: West, Supplier: Supplier C
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-04-12, Region: West, Supplier: Supplier A
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-07-31, Region: South, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-08-06, Region: Central, Supplier: Supplier D
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-02-04, Region: South, Supplier: Supplier C
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analyzing data for Date: 2024-05-25, Region: Central, Supplier: Supplier E
# Error with OpenAI GPT:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# Analysis complete. Results saved to 'supply_chain_analysis_results.csv'.

# %%
res_data=pd.read_csv("/content/supply_chain_analysis_results.csv")
res_data
# Out:
#             Date   Region    Country    Supplier  GPT Risk Analysis  \
# 0     2024-09-24  Central        USA  Supplier A                NaN
# 1     2024-02-20    South      India  Supplier B                NaN
# 2     2024-09-08     East      China  Supplier E                NaN
# 3     2024-11-26    South     Brazil  Supplier D                NaN
# 4     2024-10-01     West  Australia  Supplier D                NaN
# ...          ...      ...        ...         ...                ...
# 9995  2024-04-12     West     Brazil  Supplier A                NaN
# 9996  2024-07-31    South      India  Supplier D                NaN
# 9997  2024-08-06  Central      India  Supplier D                NaN
# 9998  2024-02-04    South    Nigeria  Supplier C                NaN
# 9999  2024-05-25  Central        USA  Supplier E                NaN
#
#                                      Sentiment Analysis
# 0     [{'label': 'neutral', 'score': 0.9522712826728...
# 1     [{'label': 'neutral', 'score': 0.8778246045112...
# 2     [{'label': 'neutral', 'score': 0.9316595792770...
# 3     [{'label': 'neutral', 'score': 0.9587573409080...
# 4     [{'label': 'neutral', 'score': 0.8311926126480...
# ...                                                 ...
# 9995  [{'label': 'neutral', 'score': 0.9567747712135...
# 9996  [{'label': 'neutral', 'score': 0.8544008731842...
# 9997  [{'label': 'neutral', 'score': 0.8544781804084...
# 9998  [{'label': 'neutral', 'score': 0.8109220862388...
# 9999  [{'label': 'neutral', 'score': 0.9522455334663...
#
# [10000 rows x 6 columns]

# %%
# @title Region vs Country

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Country'].value_counts()
    for x_label, grp in res_data.groupby('Region')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Region')
_ = plt.ylabel('Country')

# %% [markdown]
# ## Risk Alalysis 1
# using basic functions based on the value and information given in other columns

# %%
import pandas as pd

# Load dataset
def load_dataset(file_path):
    try:
        return pd.read_csv(file_path)
    except Exception as e:
        print(f"Error loading dataset: {e}")
        return None

# Analyze risk based on dataset columns
def calculate_risk(row):

    risk_score = 0

    # Low inventory increases risk
    if row['Inventory Level'] < 100:
        risk_score += 30

    # Long lead time increases risk
    if row['Lead Time (days)'] > 7:
        risk_score += 20

    # Transport status
    if row['Transport Status'] == "Delayed":
        risk_score += 40

    # Negative news sentiment increases risk
    if row['News Sentiment'] == "Negative":
        risk_score += 10

    # Return final risk factor capped at 100
    return min(risk_score, 100)

####
def main():
    dataset_path = "/content/tomato_supply_chain (1).csv"

    # Load the dataset
    data = load_dataset(dataset_path)
    if data is None:
        return

    # Add risk factor column
    data['Risk Factor'] = data.apply(calculate_risk, axis=1)

    # Display results
    print("Dataset with Risk Analysis:")
    print(data.head(10))

    # Save the updated dataset
    output_path = "tomato_supply_chain_with_risk.csv"
    data.to_csv(output_path, index=False)
    print(f"Updated dataset saved to {output_path}")

if __name__ == "__main__":
    main()
# Out:
# Dataset with Risk Analysis:
#          Date   Region    Country    Supplier  Inventory Level  \
# 0  2024-09-24  Central        USA  Supplier A              593
# 1  2024-02-20    South      India  Supplier B              784
# 2  2024-09-08     East      China  Supplier E              407
# 3  2024-11-26    South     Brazil  Supplier D              109
# 4  2024-10-01     West  Australia  Supplier D              744
# 5  2024-05-19     West    Nigeria  Supplier D               97
# 6  2024-01-19  Central     Brazil  Supplier B              143
# 7  2024-04-04  Central     Brazil  Supplier D              449
# 8  2024-01-01  Central    Nigeria  Supplier A              211
# 9  2024-04-29    South    Nigeria  Supplier E              191
#
#    Lead Time (days)   Transport Status News Sentiment  Risk Factor
# 0                10            Delayed       Negative           70
# 1                30  Awaiting Dispatch        Neutral           20
# 2                24         In Transit        Neutral           20
# 3                30  Awaiting Dispatch        Neutral           20
# 4                 4            Delayed       Negative           50
# 5                27  Awaiting Dispatch        Neutral           50
# 6                 9            On Time       Negative           30
# 7                 9  Awaiting Dispatch       Negative           30
# 8                 9            On Time        Neutral           20
# 9                19            Delayed       Positive           60
# Updated dataset saved to tomato_supply_chain_with_risk.csv

# %%
risk_data=pd.read_csv("/content/tomato_supply_chain_with_risk.csv")
risk_data
# Out:
#             Date   Region    Country    Supplier  Inventory Level  \
# 0     2024-09-24  Central        USA  Supplier A              593
# 1     2024-02-20    South      India  Supplier B              784
# 2     2024-09-08     East      China  Supplier E              407
# 3     2024-11-26    South     Brazil  Supplier D              109
# 4     2024-10-01     West  Australia  Supplier D              744
# ...          ...      ...        ...         ...              ...
# 9995  2024-04-12     West     Brazil  Supplier A              101
# 9996  2024-07-31    South      India  Supplier D              730
# 9997  2024-08-06  Central      India  Supplier D              337
# 9998  2024-02-04    South    Nigeria  Supplier C              490
# 9999  2024-05-25  Central        USA  Supplier E              623
#
#       Lead Time (days)   Transport Status News Sentiment  Risk Factor
# 0                   10            Delayed       Negative           70
# 1                   30  Awaiting Dispatch        Neutral           20
# 2                   24         In Transit        Neutral           20
# 3                   30  Awaiting Dispatch        Neutral           20
# 4                    4            Delayed       Negative           50
# ...                ...                ...            ...          ...
# 9995                 6            On Time       Positive            0
# 9996                 5         In Transit       Positive            0
# 9997                 6  Awaiting Dispatch       Positive            0
# 9998                15         In Transit       Positive           20
# 9999                 4  Awaiting Dispatch        Neutral            0
#
# [10000 rows x 9 columns]

# %% [markdown]
# ## Risk Alalysis main

# %% [markdown]
# ### model: "facebook/bart-large-mnli"

# %%
import pandas as pd
from transformers import pipeline

# Initialize the LLM model for text analysis
def initialize_llm():
    return pipeline("text-classification", model="facebook/bart-large-mnli")

# Perform risk analysis
def analyze_risk(content, llm_pipeline):
    try:
        # Analyze sentiment or risk categorization
        result = llm_pipeline(content)
        # Extract the most probable label
        risk_label = result[0]['label']
        confidence = result[0]['score']
        return risk_label, confidence
    except Exception as e:
        print(f"Error analyzing risk: {e}")
        return "Error", 0.0

# Main pipeline
def main():
    input_csv = "/content/tomato_supply_chain (1).csv"
    df = pd.read_csv(input_csv)

    llm_pipeline = initialize_llm() # Initialize LLM pipeline

    # Add new columns for risk analysis
    df["Risk Analysis"] = ""
    df["Risk Confidence"] = 0.0

    # Perform risk analysis on the "News Sentiment" column
    for index, row in df.iterrows():
        news_sentiment = row.get("News Sentiment", "No sentiment provided")
        risk_label, confidence = analyze_risk(news_sentiment, llm_pipeline)

        # Save the results into the dataframe
        df.at[index, "Risk Analysis"] = risk_label
        df.at[index, "Risk Confidence"] = confidence

        print(f"Row {index + 1}/{len(df)} analyzed. Risk: {risk_label}, Confidence: {confidence:.2f}")

    # Save the updated dataset
    output_csv = "tomato_supply_chain_with_risk_main.csv"
    df.to_csv(output_csv, index=False)
    print(f"Updated dataset with risk analysis saved to: {output_csv}")

if __name__ == "__main__":
    main()
# Out:
# Device set to use cuda:0
# Streaming output truncated to the last 5000 lines.
# Row 5002/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5003/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5004/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5005/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5006/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5007/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5008/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5009/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5010/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5011/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5012/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5013/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5014/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5015/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5016/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5017/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5018/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5019/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5020/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5021/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5022/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5023/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5024/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5025/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5026/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5027/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5028/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5029/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5030/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5031/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5032/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5033/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5034/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5035/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5036/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5037/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5038/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5039/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5040/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5041/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5042/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5043/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5044/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5045/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5046/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5047/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5048/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5049/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5050/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5051/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5052/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5053/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5054/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5055/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5056/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5057/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5058/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5059/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5060/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5061/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5062/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5063/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5064/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5065/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5066/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5067/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5068/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5069/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5070/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5071/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5072/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5073/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5074/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5075/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5076/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5077/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5078/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5079/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5080/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5081/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5082/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5083/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5084/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5085/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5086/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5087/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5088/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5089/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5090/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5091/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5092/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5093/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5094/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5095/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5096/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5097/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5098/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5099/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5100/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5101/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5102/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5103/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5104/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5105/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5106/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5107/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5108/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5109/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5110/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5111/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5112/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5113/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5114/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5115/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5116/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5117/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5118/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5119/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5120/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5121/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5122/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5123/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5124/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5125/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5126/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5127/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5128/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5129/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5130/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5131/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5132/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5133/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5134/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5135/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5136/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5137/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5138/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5139/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5140/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5141/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5142/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5143/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5144/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5145/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5146/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5147/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5148/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5149/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5150/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5151/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5152/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5153/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5154/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5155/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5156/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5157/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5158/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5159/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5160/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5161/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5162/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5163/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5164/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5165/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5166/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5167/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5168/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5169/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5170/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5171/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5172/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5173/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5174/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5175/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5176/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5177/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5178/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5179/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5180/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5181/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5182/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5183/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5184/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5185/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5186/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5187/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5188/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5189/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5190/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5191/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5192/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5193/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5194/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5195/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5196/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5197/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5198/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5199/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5200/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5201/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5202/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5203/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5204/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5205/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5206/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5207/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5208/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5209/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5210/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5211/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5212/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5213/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5214/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5215/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5216/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5217/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5218/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5219/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5220/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5221/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5222/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5223/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5224/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5225/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5226/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5227/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5228/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5229/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5230/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5231/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5232/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5233/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5234/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5235/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5236/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5237/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5238/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5239/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5240/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5241/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5242/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5243/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5244/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5245/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5246/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5247/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5248/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5249/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5250/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5251/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5252/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5253/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5254/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5255/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5256/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5257/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5258/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5259/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5260/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5261/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5262/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5263/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5264/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5265/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5266/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5267/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5268/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5269/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5270/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5271/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5272/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5273/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5274/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5275/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5276/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5277/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5278/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5279/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5280/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5281/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5282/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5283/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5284/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5285/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5286/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5287/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5288/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5289/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5290/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5291/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5292/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5293/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5294/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5295/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5296/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5297/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5298/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5299/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5300/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5301/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5302/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5303/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5304/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5305/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5306/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5307/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5308/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5309/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5310/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5311/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5312/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5313/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5314/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5315/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5316/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5317/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5318/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5319/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5320/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5321/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5322/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5323/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5324/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5325/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5326/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5327/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5328/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5329/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5330/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5331/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5332/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5333/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5334/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5335/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5336/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5337/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5338/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5339/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5340/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5341/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5342/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5343/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5344/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5345/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5346/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5347/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5348/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5349/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5350/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5351/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5352/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5353/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5354/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5355/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5356/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5357/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5358/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5359/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5360/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5361/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5362/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5363/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5364/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5365/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5366/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5367/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5368/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5369/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5370/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5371/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5372/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5373/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5374/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5375/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5376/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5377/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5378/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5379/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5380/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5381/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5382/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5383/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5384/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5385/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5386/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5387/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5388/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5389/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5390/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5391/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5392/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5393/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5394/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5395/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5396/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5397/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5398/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5399/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5400/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5401/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5402/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5403/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5404/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5405/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5406/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5407/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5408/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5409/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5410/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5411/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5412/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5413/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5414/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5415/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5416/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5417/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5418/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5419/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5420/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5421/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5422/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5423/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5424/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5425/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5426/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5427/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5428/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5429/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5430/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5431/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5432/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5433/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5434/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5435/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5436/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5437/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5438/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5439/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5440/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5441/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5442/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5443/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5444/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5445/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5446/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5447/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5448/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5449/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5450/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5451/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5452/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5453/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5454/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5455/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5456/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5457/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5458/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5459/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5460/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5461/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5462/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5463/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5464/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5465/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5466/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5467/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5468/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5469/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5470/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5471/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5472/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5473/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5474/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5475/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5476/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5477/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5478/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5479/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5480/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5481/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5482/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5483/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5484/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5485/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5486/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5487/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5488/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5489/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5490/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5491/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5492/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5493/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5494/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5495/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5496/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5497/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5498/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5499/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5500/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5501/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5502/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5503/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5504/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5505/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5506/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5507/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5508/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5509/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5510/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5511/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5512/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5513/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5514/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5515/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5516/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5517/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5518/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5519/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5520/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5521/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5522/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5523/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5524/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5525/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5526/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5527/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5528/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5529/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5530/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5531/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5532/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5533/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5534/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5535/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5536/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5537/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5538/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5539/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5540/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5541/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5542/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5543/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5544/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5545/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5546/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5547/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5548/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5549/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5550/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5551/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5552/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5553/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5554/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5555/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5556/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5557/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5558/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5559/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5560/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5561/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5562/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5563/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5564/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5565/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5566/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5567/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5568/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5569/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5570/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5571/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5572/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5573/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5574/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5575/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5576/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5577/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5578/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5579/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5580/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5581/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5582/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5583/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5584/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5585/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5586/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5587/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5588/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5589/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5590/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5591/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5592/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5593/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5594/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5595/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5596/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5597/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5598/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5599/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5600/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5601/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5602/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5603/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5604/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5605/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5606/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5607/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5608/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5609/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5610/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5611/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5612/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5613/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5614/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5615/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5616/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5617/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5618/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5619/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5620/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5621/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5622/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5623/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5624/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5625/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5626/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5627/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5628/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5629/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5630/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5631/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5632/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5633/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5634/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5635/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5636/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5637/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5638/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5639/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5640/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5641/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5642/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5643/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5644/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5645/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5646/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5647/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5648/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5649/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5650/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5651/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5652/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5653/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5654/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5655/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5656/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5657/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5658/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5659/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5660/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5661/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5662/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5663/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5664/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5665/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5666/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5667/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5668/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5669/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5670/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5671/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5672/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5673/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5674/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5675/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5676/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5677/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5678/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5679/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5680/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5681/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5682/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5683/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5684/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5685/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5686/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5687/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5688/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5689/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5690/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5691/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5692/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5693/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5694/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5695/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5696/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5697/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5698/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5699/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5700/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5701/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5702/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5703/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5704/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5705/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5706/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5707/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5708/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5709/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5710/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5711/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5712/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5713/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5714/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5715/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5716/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5717/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5718/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5719/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5720/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5721/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5722/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5723/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5724/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5725/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5726/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5727/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5728/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5729/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5730/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5731/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5732/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5733/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5734/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5735/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5736/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5737/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5738/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5739/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5740/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5741/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5742/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5743/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5744/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5745/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5746/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5747/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5748/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5749/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5750/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5751/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5752/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5753/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5754/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5755/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5756/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5757/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5758/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5759/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5760/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5761/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5762/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5763/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5764/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5765/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5766/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5767/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5768/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5769/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5770/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5771/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5772/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5773/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5774/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5775/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5776/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5777/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5778/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5779/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5780/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5781/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5782/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5783/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5784/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5785/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5786/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5787/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5788/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5789/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5790/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5791/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5792/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5793/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5794/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 5795/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5796/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5797/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 5798/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 5799/10000 analyzed. Risk: entailment, Confidence: 0.49
# ...
# Row 9736/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9737/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9738/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9739/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9740/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9741/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9742/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9743/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9744/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9745/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9746/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9747/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9748/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9749/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9750/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9751/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9752/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9753/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9754/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9755/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9756/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9757/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9758/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9759/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9760/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9761/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9762/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9763/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9764/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9765/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9766/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9767/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9768/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9769/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9770/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9771/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9772/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9773/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9774/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9775/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9776/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9777/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9778/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9779/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9780/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9781/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9782/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9783/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9784/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9785/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9786/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9787/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9788/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9789/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9790/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9791/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9792/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9793/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9794/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9795/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9796/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9797/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9798/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9799/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9800/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9801/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9802/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9803/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9804/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9805/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9806/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9807/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9808/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9809/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9810/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9811/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9812/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9813/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9814/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9815/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9816/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9817/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9818/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9819/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9820/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9821/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9822/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9823/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9824/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9825/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9826/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9827/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9828/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9829/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9830/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9831/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9832/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9833/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9834/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9835/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9836/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9837/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9838/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9839/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9840/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9841/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9842/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9843/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9844/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9845/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9846/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9847/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9848/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9849/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9850/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9851/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9852/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9853/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9854/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9855/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9856/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9857/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9858/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9859/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9860/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9861/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9862/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9863/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9864/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9865/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9866/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9867/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9868/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9869/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9870/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9871/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9872/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9873/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9874/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9875/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9876/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9877/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9878/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9879/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9880/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9881/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9882/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9883/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9884/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9885/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9886/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9887/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9888/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9889/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9890/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9891/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9892/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9893/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9894/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9895/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9896/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9897/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9898/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9899/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9900/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9901/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9902/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9903/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9904/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9905/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9906/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9907/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9908/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9909/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9910/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9911/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9912/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9913/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9914/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9915/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9916/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9917/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9918/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9919/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9920/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9921/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9922/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9923/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9924/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9925/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9926/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9927/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9928/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9929/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9930/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9931/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9932/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9933/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9934/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9935/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9936/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9937/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9938/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9939/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9940/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9941/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9942/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9943/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9944/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9945/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9946/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9947/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9948/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9949/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9950/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9951/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9952/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9953/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9954/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9955/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9956/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9957/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9958/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9959/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9960/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9961/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9962/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9963/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9964/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9965/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9966/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9967/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9968/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9969/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9970/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9971/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9972/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9973/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9974/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9975/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9976/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9977/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9978/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9979/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9980/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9981/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9982/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9983/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9984/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9985/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9986/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9987/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9988/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9989/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9990/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9991/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9992/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9993/10000 analyzed. Risk: entailment, Confidence: 0.61
# Row 9994/10000 analyzed. Risk: entailment, Confidence: 0.78
# Row 9995/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9996/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9997/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9998/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 9999/10000 analyzed. Risk: entailment, Confidence: 0.49
# Row 10000/10000 analyzed. Risk: entailment, Confidence: 0.61
# Updated dataset with risk analysis saved to: tomato_supply_chain_with_risk_main.csv

# %%
risk_data_main = pd.read_csv("/content/tomato_supply_chain_with_risk_main.csv")
risk_data_main
# Out:
#             Date   Region    Country    Supplier  Inventory Level  \
# 0     2024-09-24  Central        USA  Supplier A              593
# 1     2024-02-20    South      India  Supplier B              784
# 2     2024-09-08     East      China  Supplier E              407
# 3     2024-11-26    South     Brazil  Supplier D              109
# 4     2024-10-01     West  Australia  Supplier D              744
# ...          ...      ...        ...         ...              ...
# 9995  2024-04-12     West     Brazil  Supplier A              101
# 9996  2024-07-31    South      India  Supplier D              730
# 9997  2024-08-06  Central      India  Supplier D              337
# 9998  2024-02-04    South    Nigeria  Supplier C              490
# 9999  2024-05-25  Central        USA  Supplier E              623
#
#       Lead Time (days)   Transport Status News Sentiment Risk Factor  \
# 0                   10            Delayed       Negative      Medium
# 1                   30  Awaiting Dispatch        Neutral         Low
# 2                   24         In Transit        Neutral        High
# 3                   30  Awaiting Dispatch        Neutral      Medium
# 4                    4            Delayed       Negative         Low
# ...                ...                ...            ...         ...
# 9995                 6            On Time       Positive      Medium
# 9996                 5         In Transit       Positive         Low
# 9997                 6  Awaiting Dispatch       Positive         Low
# 9998                15         In Transit       Positive         Low
# 9999                 4  Awaiting Dispatch        Neutral      Medium
#
#      Risk Analysis  Risk Confidence
# 0       entailment         0.784987
# 1       entailment         0.610011
# 2       entailment         0.610011
# 3       entailment         0.610011
# 4       entailment         0.784987
# ...            ...              ...
# 9995    entailment         0.490097
# 9996    entailment         0.490097
# 9997    entailment         0.490097
# 9998    entailment         0.490097
# 9999    entailment         0.610011
#
# [10000 rows x 11 columns]

# %%
# @title Lead Time (days) vs Risk Confidence

from matplotlib import pyplot as plt
risk_data_main.plot(kind='scatter', x='Lead Time (days)', y='Risk Confidence', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ## Use model: cardiffnlp/twitter-roberta-base-sentiment & yiyanghkust/finbert-tone

# %%
import pandas as pd
from transformers import pipeline

# Initialize sentiment and risk models
def initialize_sentiment_model():
    return pipeline("sentiment-analysis", model="cardiffnlp/twitter-roberta-base-sentiment")

def initialize_risk_model():
    return pipeline("text-classification", model="yiyanghkust/finbert-tone")

# Analyze sentiment and risk
def analyze_sentiment_and_risk(content, sentiment_pipeline, risk_pipeline):
    try:
        # Sentiment analysis
        sentiment_results = sentiment_pipeline(content)
        sentiment_label = sentiment_results[0]['label']
        sentiment_score = sentiment_results[0]['score']

        # Risk analysis
        risk_results = risk_pipeline(content)
        risk_label = risk_results[0]['label']

        return sentiment_label, sentiment_score, risk_label
    except Exception as e:
        print(f"Error analyzing sentiment and risk: {e}")
        return "Error", 0.0, "UNKNOWN"

# Process CSV file and analyze sentiment and risk
def process_csv(file_path, sentiment_pipeline, risk_pipeline):
    try:
        # Load CSV data
        data = pd.read_csv(file_path)

        # Add new columns for sentiment and risk analysis
        data['Sentiment'] = ""
        data['Sentiment Score'] = 0.0
        data['Risk'] = ""

        for index, row in data.iterrows():
            content = f"Supply chain update: {row['Region']}, {row['Country']}, Supplier: {row['Supplier']}, Inventory Level: {row['Inventory Level']}, Lead Time: {row['Lead Time (days)']} days, Transport Status: {row['Transport Status']}, News Sentiment: {row['News Sentiment']}, Risk Factor: {row['Risk Factor']}"
            sentiment_label, sentiment_score, risk_label = analyze_sentiment_and_risk(
                content, sentiment_pipeline, risk_pipeline
            )
            data.at[index, 'Sentiment'] = sentiment_label
            data.at[index, 'Sentiment Score'] = sentiment_score
            data.at[index, 'Risk'] = risk_label

        return data
    except Exception as e:
        print(f"Error processing CSV file: {e}")
        return None

# Main pipeline
def main():
    # Initialize models
    sentiment_pipeline = initialize_sentiment_model()
    risk_pipeline = initialize_risk_model()

    # Input CSV file path (from the dataset generated earlier)
    input_csv = "/content/tomato_supply_chain (1).csv"

    # Process the CSV file
    processed_data = process_csv(input_csv, sentiment_pipeline, risk_pipeline)
    if processed_data is not None:
        # Save the processed data to a new CSV file
        output_csv = "tomato_supply_chain_analysis_1.csv"
        processed_data.to_csv(output_csv, index=False)
        print(f"Processed data saved to: {output_csv}")
    else:
        print("Failed to process CSV data.")

if __name__ == "__main__":
    main()
# Out:
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Device set to use cuda:0
# config.json:   0%|          | 0.00/533 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Device set to use cuda:0
# Processed data saved to: tomato_supply_chain_analysis_1.csv

# %%
res_data_1 = pd.read_csv("/content/tomato_supply_chain_analysis_1.csv")
res_data_1
# Out:
#             Date   Region    Country    Supplier  Inventory Level  \
# 0     2024-09-24  Central        USA  Supplier A              593
# 1     2024-02-20    South      India  Supplier B              784
# 2     2024-09-08     East      China  Supplier E              407
# 3     2024-11-26    South     Brazil  Supplier D              109
# 4     2024-10-01     West  Australia  Supplier D              744
# ...          ...      ...        ...         ...              ...
# 9995  2024-04-12     West     Brazil  Supplier A              101
# 9996  2024-07-31    South      India  Supplier D              730
# 9997  2024-08-06  Central      India  Supplier D              337
# 9998  2024-02-04    South    Nigeria  Supplier C              490
# 9999  2024-05-25  Central        USA  Supplier E              623
#
#       Lead Time (days)   Transport Status News Sentiment Risk Factor  \
# 0                   10            Delayed       Negative      Medium
# 1                   30  Awaiting Dispatch        Neutral         Low
# 2                   24         In Transit        Neutral        High
# 3                   30  Awaiting Dispatch        Neutral      Medium
# 4                    4            Delayed       Negative         Low
# ...                ...                ...            ...         ...
# 9995                 6            On Time       Positive      Medium
# 9996                 5         In Transit       Positive         Low
# 9997                 6  Awaiting Dispatch       Positive         Low
# 9998                15         In Transit       Positive         Low
# 9999                 4  Awaiting Dispatch        Neutral      Medium
#
#      Sentiment  Sentiment Score      Risk
# 0      LABEL_1         0.521802  Negative
# 1      LABEL_1         0.825231  Positive
# 2      LABEL_1         0.814744  Positive
# 3      LABEL_1         0.835494  Positive
# 4      LABEL_0         0.508282  Negative
# ...        ...              ...       ...
# 9995   LABEL_1         0.825990  Positive
# 9996   LABEL_1         0.805045  Positive
# 9997   LABEL_1         0.818170  Positive
# 9998   LABEL_1         0.772149  Positive
# 9999   LABEL_1         0.839161  Positive
#
# [10000 rows x 12 columns]

# %%
import pandas as pd
from transformers import pipeline

# Initialize sentiment and risk models
def initialize_sentiment_model():
    return pipeline("sentiment-analysis", model="cardiffnlp/twitter-roberta-base-sentiment")

def initialize_risk_model():
    return pipeline("text-classification", model="yiyanghkust/finbert-tone")

# Analyze sentiment using FinBERT
def analyze_sentiment_with_finbert(content, sentiment_pipeline):
    try:
        results = sentiment_pipeline(content)
        sentiment_label = results[0]['label']
        sentiment_score = results[0]['score']
        return sentiment_label, sentiment_score
    except Exception as e:
        print(f"Error with FinBERT Sentiment Analysis: {e}")
        return None, None

# Analyze risk using FinBERT
def analyze_risk_with_finbert(content, risk_pipeline):
    try:
        results = risk_pipeline(content)
        risk_label = results[0]['label']
        risk_score = results[0]['score']
        return risk_label, risk_score
    except Exception as e:
        print(f"Error with FinBERT Risk Analysis: {e}")
        return None, None

# Process CSV file and analyze sentiment and risk
def process_csv(file_path, sentiment_pipeline, risk_pipeline):
    try:
        # Load CSV data
        data = pd.read_csv(file_path)

        # Add new columns for sentiment and risk analysis
        data['Sentiment'] = ""
        data['Sentiment Score'] = 0.0
        data['Risk'] = ""
        data['Risk Score'] = 0.0

        for index, row in data.iterrows():
            content = f"Supply chain update: {row['Region']}, {row['Country']}, Supplier: {row['Supplier']}, Inventory Level: {row['Inventory Level']}, Lead Time: {row['Lead Time (days)']} days, Transport Status: {row['Transport Status']}, News Sentiment: {row['News Sentiment']}, Risk Factor: {row['Risk Factor']}"

            # Analyze sentiment
            sentiment_label, sentiment_score = analyze_sentiment_with_finbert(content, sentiment_pipeline)
            # Analyze risk
            risk_label, risk_score = analyze_risk_with_finbert(content, risk_pipeline)

            # Update DataFrame
            data.at[index, 'Sentiment'] = sentiment_label
            data.at[index, 'Sentiment Score'] = sentiment_score
            data.at[index, 'Risk'] = risk_label
            data.at[index, 'Risk Score'] = risk_score

        return data
    except Exception as e:
        print(f"Error processing CSV file: {e}")
        return None

# Main pipeline
def main():
    # Initialize models
    sentiment_pipeline = initialize_sentiment_model()
    risk_pipeline = initialize_risk_model()

    # Input CSV file path (from the dataset generated earlier)
    input_csv = "/content/tomato_supply_chain (1).csv"

    # Process the CSV file
    processed_data = process_csv(input_csv, sentiment_pipeline, risk_pipeline)
    if processed_data is not None:
        # Save the processed data to a new CSV file
        output_csv = "tomato_supply_chain_analysis_2.csv"
        processed_data.to_csv(output_csv, index=False)
        print(f"Processed data saved to: {output_csv}")
    else:
        print("Failed to process CSV data.")

if __name__ == "__main__":
    main()
# Out:
# Device set to use cuda:0
# Device set to use cuda:0
# Processed data saved to: tomato_supply_chain_analysis_2.csv

# %%
res_data_2 = pd.read_csv("/content/tomato_supply_chain_analysis_2.csv")
res_data_2
# Out:
#             Date   Region    Country    Supplier  Inventory Level  \
# 0     2024-09-24  Central        USA  Supplier A              593
# 1     2024-02-20    South      India  Supplier B              784
# 2     2024-09-08     East      China  Supplier E              407
# 3     2024-11-26    South     Brazil  Supplier D              109
# 4     2024-10-01     West  Australia  Supplier D              744
# ...          ...      ...        ...         ...              ...
# 9995  2024-04-12     West     Brazil  Supplier A              101
# 9996  2024-07-31    South      India  Supplier D              730
# 9997  2024-08-06  Central      India  Supplier D              337
# 9998  2024-02-04    South    Nigeria  Supplier C              490
# 9999  2024-05-25  Central        USA  Supplier E              623
#
#       Lead Time (days)   Transport Status News Sentiment Risk Factor  \
# 0                   10            Delayed       Negative      Medium
# 1                   30  Awaiting Dispatch        Neutral         Low
# 2                   24         In Transit        Neutral        High
# 3                   30  Awaiting Dispatch        Neutral      Medium
# 4                    4            Delayed       Negative         Low
# ...                ...                ...            ...         ...
# 9995                 6            On Time       Positive      Medium
# 9996                 5         In Transit       Positive         Low
# 9997                 6  Awaiting Dispatch       Positive         Low
# 9998                15         In Transit       Positive         Low
# 9999                 4  Awaiting Dispatch        Neutral      Medium
#
#      Sentiment  Sentiment Score      Risk  Risk Score
# 0      LABEL_1         0.521802  Negative    0.999995
# 1      LABEL_1         0.825231  Positive    0.721428
# 2      LABEL_1         0.814744  Positive    0.996592
# 3      LABEL_1         0.835494  Positive    0.851580
# 4      LABEL_0         0.508282  Negative    0.999995
# ...        ...              ...       ...         ...
# 9995   LABEL_1         0.825990  Positive    1.000000
# 9996   LABEL_1         0.805045  Positive    1.000000
# 9997   LABEL_1         0.818170  Positive    1.000000
# 9998   LABEL_1         0.772149  Positive    1.000000
# 9999   LABEL_1         0.839161  Positive    0.890247
#
# [10000 rows x 13 columns]

# %%
# @title Risk Score

from matplotlib import pyplot as plt
res_data_2['Risk Score'].plot(kind='hist', bins=20, title='Risk Score')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### Sentiment Score Distribution

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set a color palette
sns.set_palette("muted")

# Define a colormap for the histogram
colormap = plt.cm.viridis  # You can try other colormaps like 'plasma', 'cividis', etc.

# Plot histogram with color mapping
plt.figure(figsize=(8, 6))
n, bins, patches = plt.hist(res_data_2['Sentiment Score'], bins=20, edgecolor='black', alpha=0.8)

# Apply colors to the bars
for i in range(len(patches)):
    patches[i].set_facecolor(colormap(i / len(patches)))

# Add title and labels
plt.title("Sentiment Score Distribution", fontsize=16)
plt.xlabel("Sentiment Score", fontsize=12)
plt.ylabel("Frequency", fontsize=12)

# Customize spines visibility
plt.gca().spines[['top', 'right']].set_visible(False)

# Show plot
plt.tight_layout()
plt.show()

# %%
# @title Sentiment Score vs Risk Score

from matplotlib import pyplot as plt
res_data_2.plot(kind='scatter', x='Sentiment Score', y='Risk Score', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
